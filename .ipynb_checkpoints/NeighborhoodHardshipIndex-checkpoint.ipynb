# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
df_demographics = pd.read_csv('community_demographics.csv')
df_indicators = pd.read_csv('community_indicators.csv')

# %%
df_indicators.drop(columns=['COMMUNITY AREA NAME', 'PERCENT OF HOUSING CROWDED', 'PERCENT HOUSEHOLDS BELOW POVERTY', 'PERCENT AGED 16+ UNEMPLOYED', 'PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA', 'PERCENT AGED UNDER 18 OR OVER 64'], inplace=True)
df_indicators.columns = ['number', 'Per Capita Income', 'Hardship Index']
df_indicators.fillna(0, inplace=True)
df_indicators['number'] = df_indicators['number'].astype(int)
df_indicators.head()
# Out:
#    number  Per Capita Income  Hardship Index
# 0       1              23939            39.0
# 1       2              23040            46.0
# 2       3              35787            20.0
# 3       4              37524            17.0
# 4       5              57123             6.0

# %%
df_hardship = pd.merge(df_indicators, df_demographics, on=['number'])
# df_hardship['Percent Non Black or Hispanic'] = 100 - df_hardship['Percent Black'] - df_hardship['Percent Hispanic']
df_hardship['Percent Black'] = df_hardship['Percent Black'].str.rstrip('%').astype('float') / 100.0
df_hardship['Percent Hispanic'] = df_hardship['Percent Hispanic'].str.rstrip('%').astype('float') / 100.0
df_hardship['Percent Black and Hispanic'] = df_hardship['Percent Black'] + df_hardship['Percent Hispanic']
plot = df_hardship.plot(kind='scatter', x='Hardship Index', y='Percent Black and Hispanic', figsize=[20,10])
communities={'Rogers Park','West Ridge','Uptown','Lincoln Square','North Center','Lake View','Lincoln Park','Near North Side',
'Edison Park','Norwood Park','Jefferson Park','Forest Glen','North Park','Albany Park','Portage Park','Irving Park','Dunning',
'Montclare','Belmont Cragin','Hermosa','Avondale','Logan Square','Humboldt Park','West Town','Austin','West Garfield Park',
'East Garfield Park','Near West Side','North Lawndale','South Lawndale','Lower West Side','Loop','Near South Side','Armour Square',
'Douglas','Oakland','Fuller Park','Grand Boulevard','Kenwood','Washington Park','Hyde Park','Woodlawn','South Shore','Chatham',
'Avalon Park','South Chicago','Burnside','Calumet Heights','Roseland','Pullman','South Deering','East Side','West Pullman',
'Riverdale','Hegewisch','Garfield Ridge','Archer Heights','Brighton Park','Mckinley Park','Bridgeport','New City','West Elsdon',
'Gage Park','Clearing','West Lawn','Chicago Lawn','West Englewood','Englewood','Greater Grand Crossing','Ashburn','Auburn Gresham',
'Beverly','Washington Heights','Mount Greenwood','Morgan Park',"O'Hare",'Edgewater'}
for i, point in df_hardship.iterrows():
    if point['Community'] in communities:
        plot.text(point['Hardship Index']+1, point['Percent Black and Hispanic']-.01, str(point['Community']))
# df_hardship

# %%
list(df_hardship['Community'])
# Out:
# ['Rogers Park',
#  'West Ridge',
#  'Uptown',
#  'Lincoln Square',
#  'North Center',
#  'Lake View',
#  'Lincoln Park',
#  'Near North Side',
#  'Edison Park',
#  'Norwood Park',
#  'Jefferson Park',
#  'Forest Glen',
#  'North Park',
#  'Albany Park',
#  'Portage Park',
#  'Irving Park',
#  'Dunning',
#  'Montclare',
#  'Belmont Cragin',
#  'Hermosa',
#  'Avondale',
#  'Logan Square',
#  'Humboldt Park',
#  'West Town',
#  'Austin',
#  'West Garfield Park',
#  'East Garfield Park',
#  'Near West Side',
#  'North Lawndale',
#  'South Lawndale',
#  'Lower West Side',
#  'Loop',
#  'Near South Side',
#  'Armour Square',
#  'Douglas',
#  'Oakland',
#  'Fuller Park',
#  'Grand Boulevard',
#  'Kenwood',
#  'Washington Park',
#  'Hyde Park',
#  'Woodlawn',
#  'South Shore',
#  'Chatham',
#  'Avalon Park',
#  'South Chicago',
#  'Burnside',
#  'Calumet Heights',
#  'Roseland',
#  'Pullman',
#  'South Deering',
#  'East Side',
#  'West Pullman',
#  'Riverdale',
#  'Hegewisch',
#  'Garfield Ridge',
#  'Archer Heights',
#  'Brighton Park',
#  'Mckinley Park',
#  'Bridgeport',
#  'New City',
#  'West Elsdon',
#  'Gage Park',
#  'Clearing',
#  'West Lawn',
#  'Chicago Lawn',
#  'West Englewood',
#  'Englewood',
#  'Greater Grand Crossing',
#  'Ashburn',
#  'Auburn Gresham',
#  'Beverly',
#  'Washington Heights',
#  'Mount Greenwood',
#  'Morgan Park',
#  "O'Hare",
#  'Edgewater']

# %%
# Out:
#     number             Community_x  Per Capita Income  Hardship Index  \
# 0        1             Rogers Park              23939            39.0
# 1        2              West Ridge              23040            46.0
# 2        3                  Uptown              35787            20.0
# 3        4          Lincoln Square              37524            17.0
# 4        5            North Center              57123             6.0
# 5        6               Lake View              60058             5.0
# 6        7            Lincoln Park              71551             2.0
# 7        8         Near North Side              88669             1.0
# 8        9             Edison Park              40959             8.0
# 9       10            Norwood Park              32875            21.0
# 10      11          Jefferson Park              27751            25.0
# 11      12             Forest Glen              44164            11.0
# 12      13              North Park              26576            33.0
# 13      14             Albany Park              21323            53.0
# 14      15            Portage Park              24336            35.0
# 15      16             Irving Park              27249            34.0
# 16      17                 Dunning              26282            28.0
# 17      18              Montclaire              22014            50.0
# 18      19          Belmont Cragin              15461            70.0
# 19      20                 Hermosa              15089            71.0
# 20      21                Avondale              20039            42.0
# 21      22            Logan Square              31908            23.0
# 22      23           Humboldt park              13781            85.0
# 23      24               West Town              43198            10.0
# 24      25                  Austin              15957            73.0
# 25      26      West Garfield Park              10934            92.0
# 26      27      East Garfield Park              12961            83.0
# 27      28          Near West Side              44689            15.0
# 28      29          North Lawndale              12034            87.0
# 29      30          South Lawndale              10402            96.0
# ..     ...                     ...                ...             ...
# 47      48         Calumet Heights              28887            38.0
# 48      49                Roseland              17949            52.0
# 49      50                 Pullman              20588            51.0
# 50      51           South Deering              14685            65.0
# 51      52               East Side              17104            64.0
# 52      53            West Pullman              16563            62.0
# 53      54               Riverdale               8201            98.0
# 54      55               Hegewisch              22677            44.0
# 55      56          Garfield Ridge              26353            32.0
# 56      57          Archer Heights              16134            67.0
# 57      58           Brighton Park              13089            84.0
# 58      59           McKinley Park              16954            61.0
# 59      60              Bridgeport              22694            43.0
# 60      61                New City              12765            91.0
# 61      62             West Elsdon              15754            69.0
# 62      63               Gage Park              12171            93.0
# 63      64                Clearing              25113            29.0
# 64      65               West Lawn              16907            56.0
# 65      66            Chicago Lawn              13231            80.0
# 66      67          West Englewood              11317            89.0
# 67      68               Englewood              11888            94.0
# 68      69  Greater Grand Crossing              17285            66.0
# 69      70                 Ashburn              23482            37.0
# 70      71          Auburn Gresham              15528            74.0
# 71      72                 Beverly              39523            12.0
# 72      73       Washington Height              19713            48.0
# 73      74         Mount Greenwood              34381            16.0
# 74      75             Morgan Park              27149            30.0
# 75      76                  O'Hare              25828            24.0
# 76      77               Edgewater              33385            19.0
#
#                Community_y                                           geometry  \
# 0              Rogers Park  <Polygon><outerBoundaryIs><LinearRing><coordin...
#
# 28         91.8%             5.5%        26403.0          43.4
# 29         13.9%            82.1%        37251.0          22.5
# ..           ...              ...            ...           ...
# 47         95.9%             4.3%        48864.0          20.4
# 48         97.5%             0.5%        39377.0          23.8
# 49         84.1%             8.1%        33545.0          23.9
# 50         62.2%            30.6%        35972.0          24.6
# 51          2.9%            77.6%        42329.0          18.6
# 52         94.5%             3.7%        38675.0          25.9
# 53         97.7%             0.6%        13580.0          61.5
# 54          8.5%            43.3%        47265.0          15.3
# 55          8.7%            33.5%        55520.0           9.6
# 56          1.5%            67.8%        46207.0          12.1
# 57          1.1%            82.0%        38993.0          21.6
# 58          1.4%            61.1%        48211.0          18.5
# 59          0.8%            27.0%        47819.0          16.6
# 60         31.7%            53.2%        35819.0          33.6
# 61          2.1%            75.4%        48741.0          12.4
# 62          5.8%            85.7%        45323.0          19.1
# 63          1.0%            40.5%        53465.0           7.1
# 64          3.8%            72.8%        46558.0          16.7
# 65         56.3%            37.2%        39821.0          26.5
# 66         96.5%             1.9%        27489.0          40.2
# 67         98.8%             0.4%        20925.0          43.3
# 68         97.6%             0.6%        31843.0          32.8
# 69         49.4%            31.5%        59478.0          11.1
# 70         98.6%             0.7%        32672.0          26.4
# 71         32.1%             3.1%        87628.0           4.5
# 72         97.7%             0.4%        45366.0          16.4
# 73          4.7%             5.8%        76142.0           3.2
# 74         67.0%             2.1%        56431.0          15.2
# 75          0.5%             9.1%        48730.0          10.1
# 76         15.7%            13.7%        49316.0          17.0
#
#    Unemployment Rate Total Population
# 0               6.9%           56,125
# 1               4.4%           71,915
# 2               6.6%           60,070
# 3               4.9%           40,971
# 4               4.4%           34,623
# 5               3.0%           99,544
# 6               4.4%           69,518
# 7               5.4%           77,412
# 8               2.8%           11,715
# 9               2.3%           41,097
# 10              2.7%           28,812
# 11              2.2%           20,033
# 12              5.7%           19,249
# 13              5.9%           52,657
# 14              3.9%           66,365
# 15              4.8%           58,410
# 16              3.8%           44,664
# 17              5.1%           14,556
# 18              5.6%           81,448
# 19              8.0%           26,060
# 20              7.2%           42,187
# 21              6.6%           81,140
# 22             11.3%           57,763
# 23              5.6%           86,354
# 24             12.2%          103,304
# 25             13.9%           19,383
# 26             13.0%           20,796
# 27             13.2%           52,384
# 28             14.8%           36,243
# 29              6.8%           77,324
# ..               ...              ...
# 47              6.8%           16,431
# 48             12.4%           49,833
# 49             12.2%            7,900
# 50              7.6%           17,725
# 51              8.1%           26,608
# 52              9.9%           34,759
# 53             21.2%            5,269
# 54              5.8%           10,880
# 55              4.5%           36,636
# 56              4.9%           12,315
# 57              8.2%           45,387
# 58              6.4%           1,6192
# 59              6.2%           32,394
# 60              9.6%           47,011
# 61              5.3%           18,249
# 62              7.1%           39,981
# 63              3.8%           24,483
# 64              5.4%           33,310
# 65             11.6%           56,019
# 66             15.5%           42,329
# 67             14.3%           35,186
# 68             12.7%           37,465
# 69              6.6%           44,627
# 70             11.4%           55,258
# 71              5.1%           23,462
# 72              9.2%           28,246
# 73              3.6%           19,550
# 74              6.6%           23,357
# 75              3.4%           11,795
# 76              5.6%           57,846
#
# [77 rows x 12 columns]
